# %%
from social_data_access.social_data import SocialData

sd = SocialData()

result = sd.read('ibge.cities_with_favela_2010')
result
# Out:
#                                                          Total  \
# Brasil                                              57427999.0
# Norte                                                3988832.0
# Rondônia                                              457323.0
# Porto Velho                                           117132.0
# Acre                                                  191169.0
# ...                                                        ...
# Distrito Federal                                      774922.0
# Brasília                                              774922.0
# NaN                                                        NaN
# Fonte: IBGE, Censo Demográfico 2010.                       NaN
# Nota: Somente municípios com presença identific...         NaN
#
#                                                     Em aglomerados subnormais  \
# Brasil                                                              3224529.0
# ...

# %%
result = sd.read('ibge.cities_with_favela_2020')


result
# Out:
#                                                                                            Unnamed: 1  \
# Brasil                                                                                          Total
# NaN                                                 Com favelas, mocambos, palafitas ou assemelhad...
# Norte                                                                                           Total
# NaN                                                 Com favelas, mocambos, palafitas ou assemelhad...
# Nordeste                                                                                        Total
# ...                                                                                               ...
# Vila Propício (GO)                                                                              Total
# NaN                                                 Com favelas, mocambos, palafitas ou assemelhad...
# ...

# %%
# !pip install openpyxl
